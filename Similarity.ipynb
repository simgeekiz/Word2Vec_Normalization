# %%
from sklearn.metrics.pairwise import cosine_similarity
import generic_io

# %%
model = generic_io.load_from_file(file_path='veri/models/w2v_model_earthquake_76516.bin', file_format='pickle')

# %%
model.wv.vocab
# Out:
# {'7.1': <gensim.models.keyedvectors.Vocab at 0x7f54f58e9ac8>,
#  '#theirrawaddy': <gensim.models.keyedvectors.Vocab at 0x7f54f5c96be0>,
#  '#survivalguide': <gensim.models.keyedvectors.Vocab at 0x7f54f55150f0>,
#  '31.920': <gensim.models.keyedvectors.Vocab at 0x7f54f58c27f0>,
#  '07:58': <gensim.models.keyedvectors.Vocab at 0x7f54f597b2e8>,
#  'much.powerful': <gensim.models.keyedvectors.Vocab at 0x7f54f57a9438>,
#  'glimpse': <gensim.models.keyedvectors.Vocab at 0x7f54f542b438>,
#  '#political': <gensim.models.keyedvectors.Vocab at 0x7f54f5b40828>,
#  '#louisianaflood': <gensim.models.keyedvectors.Vocab at 0x7f54f56c8518>,
#  'ilvestoomas': <gensim.models.keyedvectors.Vocab at 0x7f54f550c320>,
#  'dust': <gensim.models.keyedvectors.Vocab at 0x7f54f5651438>,
#  'pr': <gensim.models.keyedvectors.Vocab at 0x7f54f565f8d0>,
#  'enabled': <gensim.models.keyedvectors.Vocab at 0x7f54f572c4e0>,
#  '#israel': <gensim.models.keyedvectors.Vocab at 0x7f54f5a75a58>,
# ...

# %%
model.wv.most_similar("earthqu")
# Out:
# [('earthqua', 0.9215565919876099),
#  ('earthquak', 0.9150896668434143),
#  ('ea', 0.9072723388671875),
#  ('earthq', 0.8954514861106873),
#  ('stru', 0.8892335295677185),
#  ('eart', 0.885019838809967),
#  ('ear', 0.8746320009231567),
#  ('magni', 0.8590549230575562),
#  ('str', 0.8358259201049805),
#  ('#endofdays', 0.8130565881729126)]

# %%
model.wv.similarity('earthquak', 'earthqua')
# Out:
# 0.86933157614144663
