# %%
from sklearn.metrics.pairwise import cosine_similarity
import generic_io
import editdistance

# %%
model = generic_io.load_from_file(file_path='veri/models/w2v_model_earthquake_76516.bin', file_format='pickle')

# %%
model.wv.vocab
# Out:
# {'forbid': <gensim.models.keyedvectors.Vocab at 0x7fad059207b8>,
#  'chappaqua': <gensim.models.keyedvectors.Vocab at 0x7fad059e6ac8>,
#  'z3': <gensim.models.keyedvectors.Vocab at 0x7fad0585bda0>,
#  'latrine': <gensim.models.keyedvectors.Vocab at 0x7fad05b80be0>,
#  'pal': <gensim.models.keyedvectors.Vocab at 0x7fad05a54b38>,
#  '⚪': <gensim.models.keyedvectors.Vocab at 0x7fad05de8160>,
#  'hapgood': <gensim.models.keyedvectors.Vocab at 0x7fad05f5d780>,
#  'raynet': <gensim.models.keyedvectors.Vocab at 0x7fad0614d940>,
#  'geof': <gensim.models.keyedvectors.Vocab at 0x7fad05df0748>,
#  '#rebuilt': <gensim.models.keyedvectors.Vocab at 0x7fad0588bb38>,
#  'vijaya': <gensim.models.keyedvectors.Vocab at 0x7fad05d510b8>,
#  'roster': <gensim.models.keyedvectors.Vocab at 0x7fad06011898>,
#  'avert': <gensim.models.keyedvectors.Vocab at 0x7fad05aa4208>,
#  'ज़म': <gensim.models.keyedvectors.Vocab at 0x7fad058bc7b8>,
#  '#smartphonelowpower': <gensim.models.keyedvectors.Vocab at 0x7fad05a5d550>,
#  '🍻': <gensim.models.keyedvectors.Vocab at 0x7fad05b597f0>,
#  'birmania': <gensim.models.keyedvectors.Vocab at 0x7fad05f8d9e8>,
#  '#auto': <gensim.models.keyedvectors.Vocab at 0x7fad05bea6d8>,
#  'totallycoolpix': <gensim.models.keyedvectors.Vocab at 0x7fad060b86d8>,
#  'goldman': <gensim.models.keyedvectors.Vocab at 0x7fad05bc7ba8>,
#  'starthree': <gensim.models.keyedvectors.Vocab at 0x7fad05d033c8>,
#  'allot': <gensim.models.keyedvectors.Vocab at 0x7fad060ce1d0>,
#  'commensurate': <gensim.models.keyedvectors.Vocab at 0x7fad05d3c0f0>,
#  "wsj's": <gensim.models.keyedvectors.Vocab at 0x7fad057cebe0>,
#  'sep': <gensim.models.keyedvectors.Vocab at 0x7fad059e6c88>,
#  'earthquake-struck': <gensim.models.keyedvectors.Vocab at 0x7fad05bc2400>,
#  'roundhouse': <gensim.models.keyedvectors.Vocab at 0x7fad05c88f98>,
#  'xa': <gensim.models.keyedvectors.Vocab at 0x7fad057a2080>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7fad06168fd0>,
#  '1.66': <gensim.models.keyedvectors.Vocab at 0x7fad05c7b160>,
#  '3am': <gensim.models.keyedvectors.Vocab at 0x7fad05f17588>,
#  'krlm': <gensim.models.keyedvectors.Vocab at 0x7fad05b00630>,
#  'monkeys': <gensim.models.keyedvectors.Vocab at 0x7fad060d7160>,
#  'tamples': <gensim.models.keyedvectors.Vocab at 0x7fad05d2ab00>,
#  'year.nothing': <gensim.models.keyedvectors.Vocab at 0x7fad05b05e80>,
#  'shiv': <gensim.models.keyedvectors.Vocab at 0x7fad057c1828>,
#  'hanging': <gensim.models.keyedvectors.Vocab at 0x7fad059483c8>,
#  '#coincidence': <gensim.models.keyedvectors.Vocab at 0x7fad05d4deb8>,
#  'gujarat': <gensim.models.keyedvectors.Vocab at 0x7fad059626d8>,
#  'installing': <gensim.models.keyedvectors.Vocab at 0x7fad05803908>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x7fad060395f8>,
#  'toooo': <gensim.models.keyedvectors.Vocab at 0x7fad058b7e80>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x7fad05aacac8>,
#  '\U000fe334': <gensim.models.keyedvectors.Vocab at 0x7fad05dcd668>,
#  'christchurch': <gensim.models.keyedvectors.Vocab at 0x7fad05ec3518>,
#  'ciò': <gensim.models.keyedvectors.Vocab at 0x7fad05f855f8>,
#  'procrastination': <gensim.models.keyedvectors.Vocab at 0x7fad05b78f28>,
#  '지진': <gensim.models.keyedvectors.Vocab at 0x7fad058ec278>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7fad05fd86d8>,
#  '0:01': <gensim.models.keyedvectors.Vocab at 0x7fad05fb5c88>,
#  'band': <gensim.models.keyedvectors.Vocab at 0x7fad059d9550>,
#  'slapped': <gensim.models.keyedvectors.Vocab at 0x7fad05e0b860>,
#  '#wmbd': <gensim.models.keyedvectors.Vocab at 0x7fad0598fc88>,
#  'replies': <gensim.models.keyedvectors.Vocab at 0x7fad06099470>,
#  'birmah': <gensim.models.keyedvectors.Vocab at 0x7fad05e8feb8>,
#  '#ventura': <gensim.models.keyedvectors.Vocab at 0x7fad05bbec50>,
#  '#housing': <gensim.models.keyedvectors.Vocab at 0x7fad061b8da0>,
#  '#nooffence': <gensim.models.keyedvectors.Vocab at 0x7fad05de87f0>,
#  'blabber': <gensim.models.keyedvectors.Vocab at 0x7fad05a1bba8>,
#  '#winewednesday': <gensim.models.keyedvectors.Vocab at 0x7fad05bd8400>,
#  'urgence': <gensim.models.keyedvectors.Vocab at 0x7fad05841c18>,
#  '#notallquakes': <gensim.models.keyedvectors.Vocab at 0x7fad05e44240>,
#  'hilne': <gensim.models.keyedvectors.Vocab at 0x7fad0602c588>,
#  'shitstorm': <gensim.models.keyedvectors.Vocab at 0x7fad05894550>,
#  '17000': <gensim.models.keyedvectors.Vocab at 0x7fad057c5a90>,
#  'sheva': <gensim.models.keyedvectors.Vocab at 0x7fad05a92be0>,
#  'pissa': <gensim.models.keyedvectors.Vocab at 0x7fad05b54978>,
#  'til': <gensim.models.keyedvectors.Vocab at 0x7fad06088278>,
#  "expert's": <gensim.models.keyedvectors.Vocab at 0x7fad05d0bbe0>,
#  'canton': <gensim.models.keyedvectors.Vocab at 0x7fad0604f940>,
#  '#dnevniknovetv': <gensim.models.keyedvectors.Vocab at 0x7fad057a6748>,
#  'irrevocable': <gensim.models.keyedvectors.Vocab at 0x7fad05a50c88>,
#  'ucles': <gensim.models.keyedvectors.Vocab at 0x7fad059e6470>,
#  '8008908': <gensim.models.keyedvectors.Vocab at 0x7fad05a6fba8>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x7fad06151278>,
#  '#reviewjournal': <gensim.models.keyedvectors.Vocab at 0x7fad05b1f080>,
#  'melb': <gensim.models.keyedvectors.Vocab at 0x7fad05dbccf8>,
#  'płξ': <gensim.models.keyedvectors.Vocab at 0x7fad05f6aac8>,
#  'reminds': <gensim.models.keyedvectors.Vocab at 0x7fad057c1cc0>,
#  '#quebec': <gensim.models.keyedvectors.Vocab at 0x7fad05af7a90>,
#  'inscription': <gensim.models.keyedvectors.Vocab at 0x7fad05b13ba8>,
#  '#prayfortheworld': <gensim.models.keyedvectors.Vocab at 0x7fad0601fd68>,
#  'safdarjung': <gensim.models.keyedvectors.Vocab at 0x7fad058b7550>,
#  'kono': <gensim.models.keyedvectors.Vocab at 0x7fad05abebe0>,
#  'spooky': <gensim.models.keyedvectors.Vocab at 0x7fad0579e908>,
#  '#yugvani': <gensim.models.keyedvectors.Vocab at 0x7fad05eddd30>,
#  'madonna': <gensim.models.keyedvectors.Vocab at 0x7fad05a4b978>,
#  'dave': <gensim.models.keyedvectors.Vocab at 0x7fad05acf668>,
#  'aggression': <gensim.models.keyedvectors.Vocab at 0x7fad05d76198>,
#  'recession': <gensim.models.keyedvectors.Vocab at 0x7fad05a47a90>,
#  'pain.stay': <gensim.models.keyedvectors.Vocab at 0x7fad05d93080>,
#  '#goldendeeds': <gensim.models.keyedvectors.Vocab at 0x7fad059185c0>,
#  'rug': <gensim.models.keyedvectors.Vocab at 0x7fad06069eb8>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x7fad05b1f2e8>,
#  'linking': <gensim.models.keyedvectors.Vocab at 0x7fad060ff7f0>,
#  'mimi': <gensim.models.keyedvectors.Vocab at 0x7fad05887518>,
#  's3': <gensim.models.keyedvectors.Vocab at 0x7fad05db8940>,
#  '#ticketscandal': <gensim.models.keyedvectors.Vocab at 0x7fad06183470>,
#  'sitrep': <gensim.models.keyedvectors.Vocab at 0x7fad05c1e898>,
#  'ibaraki': <gensim.models.keyedvectors.Vocab at 0x7fad059cc2e8>,
#  '\xad': <gensim.models.keyedvectors.Vocab at 0x7fad05dda518>,
#  'pledged': <gensim.models.keyedvectors.Vocab at 0x7fad060e02b0>,
#  'grimmie': <gensim.models.keyedvectors.Vocab at 0x7fad05e32fd0>,
#  'victims.be': <gensim.models.keyedvectors.Vocab at 0x7fad05f54cc0>,
#  'bens': <gensim.models.keyedvectors.Vocab at 0x7fad05cab9e8>,
#  '906': <gensim.models.keyedvectors.Vocab at 0x7fad05d64da0>,
#  'lilyallen': <gensim.models.keyedvectors.Vocab at 0x7fad05ebf7f0>,
#  'desi': <gensim.models.keyedvectors.Vocab at 0x7fad05da1dd8>,
#  '247.tthat': <gensim.models.keyedvectors.Vocab at 0x7fad05f6eac8>,
#  'ginger': <gensim.models.keyedvectors.Vocab at 0x7fad058682e8>,
#  '#antofagasta': <gensim.models.keyedvectors.Vocab at 0x7fad06103748>,
#  '012': <gensim.models.keyedvectors.Vocab at 0x7fad05d5f3c8>,
#  '#withrg': <gensim.models.keyedvectors.Vocab at 0x7fad05cc9278>,
#  'sykes': <gensim.models.keyedvectors.Vocab at 0x7fad05ef8080>,
#  'bacon-and-tomato': <gensim.models.keyedvectors.Vocab at 0x7fad0604f198>,
#  'tribes': <gensim.models.keyedvectors.Vocab at 0x7fad05c7fef0>,
#  'の地震がヒット': <gensim.models.keyedvectors.Vocab at 0x7fad05d76cf8>,
#  'transmutation': <gensim.models.keyedvectors.Vocab at 0x7fad057fb748>,
#  'align': <gensim.models.keyedvectors.Vocab at 0x7fad05ef06d8>,
#  'shake-table': <gensim.models.keyedvectors.Vocab at 0x7fad061b2438>,
#  'mars': <gensim.models.keyedvectors.Vocab at 0x7fad05d03f60>,
#  'geoegeclooney': <gensim.models.keyedvectors.Vocab at 0x7fad060f20b8>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x7fad05d419b0>,
#  'ys': <gensim.models.keyedvectors.Vocab at 0x7fad05f4b8d0>,
#  '#pornography': <gensim.models.keyedvectors.Vocab at 0x7fad06149438>,
#  'nfi': <gensim.models.keyedvectors.Vocab at 0x7fad05a54f60>,
#  '#coalinga': <gensim.models.keyedvectors.Vocab at 0x7fad05c60d68>,
#  '#narendramodi': <gensim.models.keyedvectors.Vocab at 0x7fad0598ac88>,
#  "bangladesh's": <gensim.models.keyedvectors.Vocab at 0x7fad05c53d30>,
#  'gelo': <gensim.models.keyedvectors.Vocab at 0x7fad05d8b748>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7fad05e81e48>,
#  'rrsक': <gensim.models.keyedvectors.Vocab at 0x7fad05c346a0>,
#  'perugia.and': <gensim.models.keyedvectors.Vocab at 0x7fad06069630>,
#  'botha': <gensim.models.keyedvectors.Vocab at 0x7fad06030da0>,
#  'hs': <gensim.models.keyedvectors.Vocab at 0x7fad05e2e3c8>,
#  'blizz': <gensim.models.keyedvectors.Vocab at 0x7fad05d267b8>,
#  'labotomy': <gensim.models.keyedvectors.Vocab at 0x7fad06115048>,
#  "al'amaatriciana": <gensim.models.keyedvectors.Vocab at 0x7fad05f80358>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7fad05ce8278>,
#  '#gps': <gensim.models.keyedvectors.Vocab at 0x7fad0593f518>,
#  'requirement': <gensim.models.keyedvectors.Vocab at 0x7fad0592eb38>,
#  'aseismic': <gensim.models.keyedvectors.Vocab at 0x7fad0606e240>,
#  'signature': <gensim.models.keyedvectors.Vocab at 0x7fad05e25f98>,
#  '3.30': <gensim.models.keyedvectors.Vocab at 0x7fad060b0e10>,
#  '#mile': <gensim.models.keyedvectors.Vocab at 0x7fad05ce8cc0>,
#  'menambahkan': <gensim.models.keyedvectors.Vocab at 0x7fad05f66a90>,
#  'spgc': <gensim.models.keyedvectors.Vocab at 0x7fad05c6eda0>,
#  'pesticides': <gensim.models.keyedvectors.Vocab at 0x7fad05e781d0>,
#  'migh': <gensim.models.keyedvectors.Vocab at 0x7fad05d8b400>,
#  'yokohama': <gensim.models.keyedvectors.Vocab at 0x7fad05db8080>,
#  "jenna's": <gensim.models.keyedvectors.Vocab at 0x7fad061458d0>,
#  'hague': <gensim.models.keyedvectors.Vocab at 0x7fad05c42dd8>,
#  'chemtrailing': <gensim.models.keyedvectors.Vocab at 0x7fad05db8048>,
#  'underwo': <gensim.models.keyedvectors.Vocab at 0x7fad05d570b8>,
#  'massy': <gensim.models.keyedvectors.Vocab at 0x7fad05769470>,
#  'droneblog': <gensim.models.keyedvectors.Vocab at 0x7fad05f28550>,
#  'seismiczone': <gensim.models.keyedvectors.Vocab at 0x7fad05c34390>,
#  '05:02': <gensim.models.keyedvectors.Vocab at 0x7fad05da6d68>,
#  "calcio's": <gensim.models.keyedvectors.Vocab at 0x7fad059b6898>,
#  '2.12': <gensim.models.keyedvectors.Vocab at 0x7fad05d76400>,
#  'omaha': <gensim.models.keyedvectors.Vocab at 0x7fad057f29b0>,
#  "#winnipeg's": <gensim.models.keyedvectors.Vocab at 0x7fad05ed1a58>,
#  'brod': <gensim.models.keyedvectors.Vocab at 0x7fad05f736d8>,
#  '【': <gensim.models.keyedvectors.Vocab at 0x7fad05adc6d8>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7fad05b4fd68>,
#  'mag.quake': <gensim.models.keyedvectors.Vocab at 0x7fad060f6f28>,
#  'crushes': <gensim.models.keyedvectors.Vocab at 0x7fad05f2ce10>,
#  'revolving': <gensim.models.keyedvectors.Vocab at 0x7fad05764c50>,
#  'hiker': <gensim.models.keyedvectors.Vocab at 0x7fad0592edd8>,
#  'sanju': <gensim.models.keyedvectors.Vocab at 0x7fad057f24a8>,
#  'kintu': <gensim.models.keyedvectors.Vocab at 0x7fad06157278>,
#  'renz': <gensim.models.keyedvectors.Vocab at 0x7fad059200b8>,
#  'solidarietá': <gensim.models.keyedvectors.Vocab at 0x7fad061b2b00>,
#  '#commonfloor': <gensim.models.keyedvectors.Vocab at 0x7fad05c84eb8>,
#  'breathtaking': <gensim.models.keyedvectors.Vocab at 0x7fad057169e8>,
#  'bhagwati': <gensim.models.keyedvectors.Vocab at 0x7fad05d4d8d0>,
#  '伊中部地震': <gensim.models.keyedvectors.Vocab at 0x7fad057f6438>,
#  '#poem': <gensim.models.keyedvectors.Vocab at 0x7fad05810a90>,
#  '46.0': <gensim.models.keyedvectors.Vocab at 0x7fad05bbebe0>,
#  '#makeinindia': <gensim.models.keyedvectors.Vocab at 0x7fad06060a20>,
#  'lillah': <gensim.models.keyedvectors.Vocab at 0x7fad05da1d30>,
#  'coincidence': <gensim.models.keyedvectors.Vocab at 0x7fad05711f28>,
#  'windfall': <gensim.models.keyedvectors.Vocab at 0x7fad05e970b8>,
#  'after-shock': <gensim.models.keyedvectors.Vocab at 0x7fad05a6f588>,
#  '#lokanthali': <gensim.models.keyedvectors.Vocab at 0x7fad05d7ea58>,
#  'brkng': <gensim.models.keyedvectors.Vocab at 0x7fad05aee7f0>,
#  '#suaju': <gensim.models.keyedvectors.Vocab at 0x7fad059bf278>,
#  'buyildings': <gensim.models.keyedvectors.Vocab at 0x7fad05a24b38>,
#  'soo': <gensim.models.keyedvectors.Vocab at 0x7fad0583d908>,
#  'drying': <gensim.models.keyedvectors.Vocab at 0x7fad05cc6b38>,
#  'adept': <gensim.models.keyedvectors.Vocab at 0x7fad05bc7ef0>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x7fad057e4d68>,
#  'abim': <gensim.models.keyedvectors.Vocab at 0x7fad05be5be0>,
#  '#jakarta': <gensim.models.keyedvectors.Vocab at 0x7fad05c95240>,
#  'tweeting': <gensim.models.keyedvectors.Vocab at 0x7fad05d4d4a8>,
#  'nalty': <gensim.models.keyedvectors.Vocab at 0x7fad05c5ceb8>,
#  'estructuras': <gensim.models.keyedvectors.Vocab at 0x7fad05d41ba8>,
#  '#numeri': <gensim.models.keyedvectors.Vocab at 0x7fad05c272e8>,
#  'ot': <gensim.models.keyedvectors.Vocab at 0x7fad05849470>,
#  'council': <gensim.models.keyedvectors.Vocab at 0x7fad0613c860>,
#  'earthbender': <gensim.models.keyedvectors.Vocab at 0x7fad05f09be0>,
#  'propane': <gensim.models.keyedvectors.Vocab at 0x7fad05abea90>,
#  'mounties': <gensim.models.keyedvectors.Vocab at 0x7fad05c1a160>,
#  '🍸': <gensim.models.keyedvectors.Vocab at 0x7fad0581e198>,
#  'fireworks': <gensim.models.keyedvectors.Vocab at 0x7fad05955240>,
#  'incurred': <gensim.models.keyedvectors.Vocab at 0x7fad05a3fe80>,
#  'mazdas': <gensim.models.keyedvectors.Vocab at 0x7fad05a01e80>,
#  'vide': <gensim.models.keyedvectors.Vocab at 0x7fad05e48cf8>,
#  'ळमधल': <gensim.models.keyedvectors.Vocab at 0x7fad060bd4e0>,
#  'air-force': <gensim.models.keyedvectors.Vocab at 0x7fad05a3f710>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x7fad05b05278>,
#  'ora': <gensim.models.keyedvectors.Vocab at 0x7fad05df4be0>,
#  '#jarabulus': <gensim.models.keyedvectors.Vocab at 0x7fad05a6a240>,
#  'wien': <gensim.models.keyedvectors.Vocab at 0x7fad05cf26a0>,
#  'díganle': <gensim.models.keyedvectors.Vocab at 0x7fad05df4da0>,
#  'gazzettadelsud': <gensim.models.keyedvectors.Vocab at 0x7fad05ad4128>,
#  'momina': <gensim.models.keyedvectors.Vocab at 0x7fad05937588>,
#  'jstadium': <gensim.models.keyedvectors.Vocab at 0x7fad060edbe0>,
#  'ish': <gensim.models.keyedvectors.Vocab at 0x7fad0572c8d0>,
#  'wral': <gensim.models.keyedvectors.Vocab at 0x7fad05b42588>,
#  'cnnireport': <gensim.models.keyedvectors.Vocab at 0x7fad05acbd30>,
#  'endurance': <gensim.models.keyedvectors.Vocab at 0x7fad0588fda0>,
#  'wore': <gensim.models.keyedvectors.Vocab at 0x7fad058de400>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x7fad05e59940>,
#  'lasta': <gensim.models.keyedvectors.Vocab at 0x7fad05c889b0>,
#  'grade-creating': <gensim.models.keyedvectors.Vocab at 0x7fad05711160>,
#  '#iddr': <gensim.models.keyedvectors.Vocab at 0x7fad05c1ab38>,
#  '12301485': <gensim.models.keyedvectors.Vocab at 0x7fad060082e8>,
#  'shantonil': <gensim.models.keyedvectors.Vocab at 0x7fad06119b70>,
#  'urging': <gensim.models.keyedvectors.Vocab at 0x7fad05932ef0>,
#  'shel': <gensim.models.keyedvectors.Vocab at 0x7fad0615f128>,
#  '#nj': <gensim.models.keyedvectors.Vocab at 0x7fad05b47780>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x7fad0617ab00>,
#  'doubled': <gensim.models.keyedvectors.Vocab at 0x7fad058c5828>,
#  '#thanks4concern': <gensim.models.keyedvectors.Vocab at 0x7fad05e0fe80>,
#  'interrupt': <gensim.models.keyedvectors.Vocab at 0x7fad060b0470>,
#  '#shobhade': <gensim.models.keyedvectors.Vocab at 0x7fad059079b0>,
#  '#indiawithne': <gensim.models.keyedvectors.Vocab at 0x7fad058f04a8>,
#  'manciata': <gensim.models.keyedvectors.Vocab at 0x7fad05ba3390>,
#  'nathalie': <gensim.models.keyedvectors.Vocab at 0x7fad0611d908>,
#  '3.5-': <gensim.models.keyedvectors.Vocab at 0x7fad05bfc128>,
#  'यव': <gensim.models.keyedvectors.Vocab at 0x7fad05a052e8>,
#  '#ansa': <gensim.models.keyedvectors.Vocab at 0x7fad05f47080>,
#  'geotechnical': <gensim.models.keyedvectors.Vocab at 0x7fad05d2a128>,
#  'amidst': <gensim.models.keyedvectors.Vocab at 0x7fad0596c860>,
#  '1985': <gensim.models.keyedvectors.Vocab at 0x7fad0577b748>,
#  '#slide': <gensim.models.keyedvectors.Vocab at 0x7fad05bc2eb8>,
#  '#helplinenumbers': <gensim.models.keyedvectors.Vocab at 0x7fad05b426a0>,
#  'victoms': <gensim.models.keyedvectors.Vocab at 0x7fad0609e710>,
#  'teams': <gensim.models.keyedvectors.Vocab at 0x7fad060f2b70>,
#  'usu': <gensim.models.keyedvectors.Vocab at 0x7fad05948908>,
#  '#ms': <gensim.models.keyedvectors.Vocab at 0x7fad05c2c780>,
#  'babe': <gensim.models.keyedvectors.Vocab at 0x7fad0572c128>,
#  '18:11': <gensim.models.keyedvectors.Vocab at 0x7fad06119940>,
#  '#homeschooling': <gensim.models.keyedvectors.Vocab at 0x7fad057ff240>,
#  'mikayel': <gensim.models.keyedvectors.Vocab at 0x7fad05ddf128>,
#  'elina': <gensim.models.keyedvectors.Vocab at 0x7fad057e4438>,
#  'firstly': <gensim.models.keyedvectors.Vocab at 0x7fad05beef60>,
#  'argentine': <gensim.models.keyedvectors.Vocab at 0x7fad05e36978>,
#  'intermediate': <gensim.models.keyedvectors.Vocab at 0x7fad06060c88>,
#  'lamjung': <gensim.models.keyedvectors.Vocab at 0x7fad05aacf28>,
#  'odisha': <gensim.models.keyedvectors.Vocab at 0x7fad0615b908>,
#  'bests': <gensim.models.keyedvectors.Vocab at 0x7fad0571edd8>,
#  'nefy': <gensim.models.keyedvectors.Vocab at 0x7fad0610b1d0>,
#  'pinellas': <gensim.models.keyedvectors.Vocab at 0x7fad0575c5f8>,
#  'himalayas': <gensim.models.keyedvectors.Vocab at 0x7fad05e55748>,
#  'reported.ly': <gensim.models.keyedvectors.Vocab at 0x7fad05b662e8>,
#  '180-200': <gensim.models.keyedvectors.Vocab at 0x7fad06039898>,
#  'cairo': <gensim.models.keyedvectors.Vocab at 0x7fad05bddcc0>,
#  '#jeremycorbyn': <gensim.models.keyedvectors.Vocab at 0x7fad05822e10>,
#  '1987': <gensim.models.keyedvectors.Vocab at 0x7fad0587fda0>,
#  'mizuki': <gensim.models.keyedvectors.Vocab at 0x7fad05e5eb38>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x7fad06042eb8>,
#  'activado': <gensim.models.keyedvectors.Vocab at 0x7fad05fbe4e0>,
#  'quake-live': <gensim.models.keyedvectors.Vocab at 0x7fad05d49208>,
#  '#gasmaffia': <gensim.models.keyedvectors.Vocab at 0x7fad05e626a0>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x7fad05fc2588>,
#  '1,457': <gensim.models.keyedvectors.Vocab at 0x7fad05df4ac8>,
#  'ww': <gensim.models.keyedvectors.Vocab at 0x7fad05e072e8>,
#  'hero': <gensim.models.keyedvectors.Vocab at 0x7fad05cb8358>,
#  '#liveonkmtr': <gensim.models.keyedvectors.Vocab at 0x7fad05d57630>,
#  'wedne': <gensim.models.keyedvectors.Vocab at 0x7fad061c08d0>,
#  '#thebreakfastclub': <gensim.models.keyedvectors.Vocab at 0x7fad059efa90>,
#  'big-ass': <gensim.models.keyedvectors.Vocab at 0x7fad06183e10>,
#  'initiatives': <gensim.models.keyedvectors.Vocab at 0x7fad0582f978>,
#  "tita's": <gensim.models.keyedvectors.Vocab at 0x7fad057117f0>,
#  'corriere': <gensim.models.keyedvectors.Vocab at 0x7fad05c08908>,
#  '#gaytravel': <gensim.models.keyedvectors.Vocab at 0x7fad05e25da0>,
#  '92km': <gensim.models.keyedvectors.Vocab at 0x7fad059868d0>,
#  'adra': <gensim.models.keyedvectors.Vocab at 0x7fad05e07278>,
#  'masala.trp': <gensim.models.keyedvectors.Vocab at 0x7fad05eeb4e0>,
#  'worldでbreaking': <gensim.models.keyedvectors.Vocab at 0x7fad060b41d0>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7fad05b17e10>,
#  'jamelle': <gensim.models.keyedvectors.Vocab at 0x7fad05cfaa90>,
#  '200s': <gensim.models.keyedvectors.Vocab at 0x7fad05b35470>,
#  '#sperlonga': <gensim.models.keyedvectors.Vocab at 0x7fad057f2c88>,
#  'farmer': <gensim.models.keyedvectors.Vocab at 0x7fad05a62ef0>,
#  '#italyearhquake': <gensim.models.keyedvectors.Vocab at 0x7fad060e9588>,
#  'subdued': <gensim.models.keyedvectors.Vocab at 0x7fad05e70438>,
#  'seated': <gensim.models.keyedvectors.Vocab at 0x7fad05fcb470>,
#  'bittu': <gensim.models.keyedvectors.Vocab at 0x7fad0611d630>,
#  'mydaughterwas': <gensim.models.keyedvectors.Vocab at 0x7fad05bd3128>,
#  'gunung': <gensim.models.keyedvectors.Vocab at 0x7fad059936a0>,
#  'biharstorm': <gensim.models.keyedvectors.Vocab at 0x7fad05777a58>,
#  '#sntic': <gensim.models.keyedvectors.Vocab at 0x7fad05fc7f28>,
#  '220,000': <gensim.models.keyedvectors.Vocab at 0x7fad05cb02b0>,
#  'heartache': <gensim.models.keyedvectors.Vocab at 0x7fad05f05278>,
#  '\uf62d': <gensim.models.keyedvectors.Vocab at 0x7fad05fdd358>,
#  'planes': <gensim.models.keyedvectors.Vocab at 0x7fad05764b00>,
#  'efl': <gensim.models.keyedvectors.Vocab at 0x7fad05a5def0>,
#  '12.06': <gensim.models.keyedvectors.Vocab at 0x7fad05b300b8>,
#  'ilaria': <gensim.models.keyedvectors.Vocab at 0x7fad05b54438>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7fad05c88b00>,
#  'sputnikint': <gensim.models.keyedvectors.Vocab at 0x7fad058b7e48>,
#  'badalamenti': <gensim.models.keyedvectors.Vocab at 0x7fad05fb0080>,
#  '3200': <gensim.models.keyedvectors.Vocab at 0x7fad05a28c88>,
#  '#badtiming': <gensim.models.keyedvectors.Vocab at 0x7fad05c422b0>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x7fad05eb6438>,
#  '\U000fec2c': <gensim.models.keyedvectors.Vocab at 0x7fad05da6e48>,
#  '่': <gensim.models.keyedvectors.Vocab at 0x7fad05aac550>,
#  'sights': <gensim.models.keyedvectors.Vocab at 0x7fad060f6e48>,
#  'fulfilling': <gensim.models.keyedvectors.Vocab at 0x7fad059de828>,
#  '#newsbeatworld': <gensim.models.keyedvectors.Vocab at 0x7fad06171cc0>,
#  'cuando': <gensim.models.keyedvectors.Vocab at 0x7fad05b6abe0>,
#  'yondii': <gensim.models.keyedvectors.Vocab at 0x7fad05c7f518>,
#  'gets.and': <gensim.models.keyedvectors.Vocab at 0x7fad060b0ef0>,
#  '#volksbetrug': <gensim.models.keyedvectors.Vocab at 0x7fad06138e10>,
#  '#infn': <gensim.models.keyedvectors.Vocab at 0x7fad058a65f8>,
#  'ミャンマー中部でm': <gensim.models.keyedvectors.Vocab at 0x7fad05f1b940>,
#  'reckter': <gensim.models.keyedvectors.Vocab at 0x7fad059d5198>,
#  'amcits': <gensim.models.keyedvectors.Vocab at 0x7fad06008eb8>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7fad05b4bfd0>,
#  'ඉවරය': <gensim.models.keyedvectors.Vocab at 0x7fad05dc0a58>,
#  '24,2016': <gensim.models.keyedvectors.Vocab at 0x7fad05f78f28>,
#  'kidnap': <gensim.models.keyedvectors.Vocab at 0x7fad05d83b00>,
#  'condol': <gensim.models.keyedvectors.Vocab at 0x7fad05c65550>,
#  '#editorial': <gensim.models.keyedvectors.Vocab at 0x7fad05de8c18>,
#  'connationals': <gensim.models.keyedvectors.Vocab at 0x7fad05c23ac8>,
#  'wounded': <gensim.models.keyedvectors.Vocab at 0x7fad05a9f128>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x7fad05b54780>,
#  'with_winner': <gensim.models.keyedvectors.Vocab at 0x7fad05a96e80>,
#  'aqualoreto': <gensim.models.keyedvectors.Vocab at 0x7fad0596ce10>,
#  'burdwan': <gensim.models.keyedvectors.Vocab at 0x7fad05e9b898>,
#  'ou': <gensim.models.keyedvectors.Vocab at 0x7fad0601a9e8>,
#  '#blurredbutstillhot': <gensim.models.keyedvectors.Vocab at 0x7fad05bf2ef0>,
#  'muslism': <gensim.models.keyedvectors.Vocab at 0x7fad05f96fd0>,
#  'managua': <gensim.models.keyedvectors.Vocab at 0x7fad058b3550>,
#  'resorts': <gensim.models.keyedvectors.Vocab at 0x7fad05d0bfd0>,
#  'zac': <gensim.models.keyedvectors.Vocab at 0x7fad05e97e80>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7fad05cb4b38>,
#  '#italye': <gensim.models.keyedvectors.Vocab at 0x7fad05c04080>,
#  'buenos': <gensim.models.keyedvectors.Vocab at 0x7fad060654e0>,
#  '#colori': <gensim.models.keyedvectors.Vocab at 0x7fad057c1080>,
#  'edm': <gensim.models.keyedvectors.Vocab at 0x7fad05b66cc0>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7fad05a73c88>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x7fad0614d748>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7fad05711b38>,
#  '2.6': <gensim.models.keyedvectors.Vocab at 0x7fad05bd3780>,
#  '#eptip': <gensim.models.keyedvectors.Vocab at 0x7fad05bbadd8>,
#  'सह': <gensim.models.keyedvectors.Vocab at 0x7fad05bfc0b8>,
#  "nonna's": <gensim.models.keyedvectors.Vocab at 0x7fad05b35668>,
#  '13.0': <gensim.models.keyedvectors.Vocab at 0x7fad05d1d048>,
#  'vancouver': <gensim.models.keyedvectors.Vocab at 0x7fad05997da0>,
#  '#senzavergogna': <gensim.models.keyedvectors.Vocab at 0x7fad0591c0f0>,
#  'shelther': <gensim.models.keyedvectors.Vocab at 0x7fad060c14a8>,
#  'respo': <gensim.models.keyedvectors.Vocab at 0x7fad05d1db38>,
#  'guid': <gensim.models.keyedvectors.Vocab at 0x7fad05bbaa20>,
#  'cyber-attack': <gensim.models.keyedvectors.Vocab at 0x7fad05f24208>,
#  'cher': <gensim.models.keyedvectors.Vocab at 0x7fad05bbaba8>,
#  '일으키지': <gensim.models.keyedvectors.Vocab at 0x7fad05f32be0>,
#  'partite': <gensim.models.keyedvectors.Vocab at 0x7fad058ae748>,
#  'raquel': <gensim.models.keyedvectors.Vocab at 0x7fad05fd8048>,
#  '🌻': <gensim.models.keyedvectors.Vocab at 0x7fad05eccd68>,
#  '#monashstructeng': <gensim.models.keyedvectors.Vocab at 0x7fad0611d0f0>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x7fad05ee22e8>,
#  'iske': <gensim.models.keyedvectors.Vocab at 0x7fad05cf63c8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fad05b179e8>,
#  'enex': <gensim.models.keyedvectors.Vocab at 0x7fad05dfe198>,
#  'rethinks': <gensim.models.keyedvectors.Vocab at 0x7fad0586ccf8>,
#  'texted': <gensim.models.keyedvectors.Vocab at 0x7fad0596c198>,
#  'kat': <gensim.models.keyedvectors.Vocab at 0x7fad05ca7c88>,
#  '#saveitalylord': <gensim.models.keyedvectors.Vocab at 0x7fad05bba198>,
#  'imams': <gensim.models.keyedvectors.Vocab at 0x7fad05adc048>,
#  'toolkit': <gensim.models.keyedvectors.Vocab at 0x7fad05c11320>,
#  'quint': <gensim.models.keyedvectors.Vocab at 0x7fad057bdc50>,
#  'weaponry': <gensim.models.keyedvectors.Vocab at 0x7fad05ef09e8>,
#  'freezing': <gensim.models.keyedvectors.Vocab at 0x7fad05d45358>,
#  '#napaquake': <gensim.models.keyedvectors.Vocab at 0x7fad059ebd30>,
#  'magniutude': <gensim.models.keyedvectors.Vocab at 0x7fad05777390>,
#  'bell': <gensim.models.keyedvectors.Vocab at 0x7fad05d76748>,
#  'understan': <gensim.models.keyedvectors.Vocab at 0x7fad05bbab38>,
#  'chilling': <gensim.models.keyedvectors.Vocab at 0x7fad05a1b7b8>,
#  '\U000fe321': <gensim.models.keyedvectors.Vocab at 0x7fad05856dd8>,
#  '#officials': <gensim.models.keyedvectors.Vocab at 0x7fad05aac2b0>,
#  'swt': <gensim.models.keyedvectors.Vocab at 0x7fad059136d8>,
#  'backlash': <gensim.models.keyedvectors.Vocab at 0x7fad057b41d0>,
#  'hints': <gensim.models.keyedvectors.Vocab at 0x7fad05a9fcf8>,
#  'pyrocastic': <gensim.models.keyedvectors.Vocab at 0x7fad060c6e48>,
#  '1:55': <gensim.models.keyedvectors.Vocab at 0x7fad05f17710>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7fad06084470>,
#  'ddnational': <gensim.models.keyedvectors.Vocab at 0x7fad060a2a58>,
#  'patria': <gensim.models.keyedvectors.Vocab at 0x7fad06157f60>,
#  "jonty's": <gensim.models.keyedvectors.Vocab at 0x7fad057ed320>,
#  '#almamun': <gensim.models.keyedvectors.Vocab at 0x7fad05974cc0>,
#  'lip': <gensim.models.keyedvectors.Vocab at 0x7fad059f8048>,
#  "eq's": <gensim.models.keyedvectors.Vocab at 0x7fad05c27eb8>,
#  "#assad's": <gensim.models.keyedvectors.Vocab at 0x7fad05f6a940>,
#  'felts': <gensim.models.keyedvectors.Vocab at 0x7fad05e93208>,
#  '0.45500': <gensim.models.keyedvectors.Vocab at 0x7fad05e673c8>,
#  'kyoto': <gensim.models.keyedvectors.Vocab at 0x7fad060655f8>,
#  '167.49': <gensim.models.keyedvectors.Vocab at 0x7fad05cc6898>,
#  '#wakeupwi': <gensim.models.keyedvectors.Vocab at 0x7fad0574f4a8>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7fad05d416d8>,
#  '16min': <gensim.models.keyedvectors.Vocab at 0x7fad05764ba8>,
#  'wdr': <gensim.models.keyedvectors.Vocab at 0x7fad05ce06d8>,
#  '02:28': <gensim.models.keyedvectors.Vocab at 0x7fad0585be10>,
#  'foundraise': <gensim.models.keyedvectors.Vocab at 0x7fad05871a90>,
#  'worries': <gensim.models.keyedvectors.Vocab at 0x7fad05e86400>,
#  'hawking': <gensim.models.keyedvectors.Vocab at 0x7fad05d262b0>,
#  '#standards': <gensim.models.keyedvectors.Vocab at 0x7fad05d93048>,
#  '#dn': <gensim.models.keyedvectors.Vocab at 0x7fad05ce07f0>,
#  'brownies': <gensim.models.keyedvectors.Vocab at 0x7fad061c06a0>,
#  '#footage': <gensim.models.keyedvectors.Vocab at 0x7fad05b1fef0>,
#  'bangladesh': <gensim.models.keyedvectors.Vocab at 0x7fad060d3518>,
#  'donegal': <gensim.models.keyedvectors.Vocab at 0x7fad05c53da0>,
#  '#teremoto': <gensim.models.keyedvectors.Vocab at 0x7fad059a0400>,
#  'lathe': <gensim.models.keyedvectors.Vocab at 0x7fad05cab240>,
#  'pron': <gensim.models.keyedvectors.Vocab at 0x7fad0613c0f0>,
#  '21:59': <gensim.models.keyedvectors.Vocab at 0x7fad060695f8>,
#  'tagle': <gensim.models.keyedvectors.Vocab at 0x7fad05d99940>,
#  'government-in-exile': <gensim.models.keyedvectors.Vocab at 0x7fad059937f0>,
#  "laverne's": <gensim.models.keyedvectors.Vocab at 0x7fad058f5e10>,
#  'echoed': <gensim.models.keyedvectors.Vocab at 0x7fad05dae7b8>,
#  'sinks': <gensim.models.keyedvectors.Vocab at 0x7fad05e70ef0>,
#  'breakup': <gensim.models.keyedvectors.Vocab at 0x7fad05dfe5f8>,
#  'exit': <gensim.models.keyedvectors.Vocab at 0x7fad05ea94a8>,
#  'causale': <gensim.models.keyedvectors.Vocab at 0x7fad057f2470>,
#  '#msghelpearthquak': <gensim.models.keyedvectors.Vocab at 0x7fad05e023c8>,
#  '#viwidausa': <gensim.models.keyedvectors.Vocab at 0x7fad059bbfd0>,
#  'economist': <gensim.models.keyedvectors.Vocab at 0x7fad05f54400>,
#  'sana': <gensim.models.keyedvectors.Vocab at 0x7fad058ecdd8>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x7fad0615bb38>,
#  '#gcseresults': <gensim.models.keyedvectors.Vocab at 0x7fad05dd5080>,
#  '#whattimedoyoucallthis': <gensim.models.keyedvectors.Vocab at 0x7fad05a12a20>,
#  'learnt': <gensim.models.keyedvectors.Vocab at 0x7fad060306a0>,
#  '#malta': <gensim.models.keyedvectors.Vocab at 0x7fad05711a20>,
#  'dm': <gensim.models.keyedvectors.Vocab at 0x7fad060912b0>,
#  'wtae': <gensim.models.keyedvectors.Vocab at 0x7fad05cc9630>,
#  '#portcharlotte': <gensim.models.keyedvectors.Vocab at 0x7fad05dc97f0>,
#  'lifelong': <gensim.models.keyedvectors.Vocab at 0x7fad05d195f8>,
#  'whic': <gensim.models.keyedvectors.Vocab at 0x7fad05b66b38>,
#  '3:30': <gensim.models.keyedvectors.Vocab at 0x7fad05d152b0>,
#  'forestry': <gensim.models.keyedvectors.Vocab at 0x7fad05f89dd8>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7fad0574f6a0>,
#  'cardinal': <gensim.models.keyedvectors.Vocab at 0x7fad05bfcf60>,
#  'russian': <gensim.models.keyedvectors.Vocab at 0x7fad05970828>,
#  'ziemię': <gensim.models.keyedvectors.Vocab at 0x7fad05a8d6d8>,
#  'lippiano': <gensim.models.keyedvectors.Vocab at 0x7fad060658d0>,
#  'cagata': <gensim.models.keyedvectors.Vocab at 0x7fad05a782e8>,
#  'sympathys': <gensim.models.keyedvectors.Vocab at 0x7fad05aa8208>,
#  "afp's": <gensim.models.keyedvectors.Vocab at 0x7fad05c60a20>,
#  'real-time': <gensim.models.keyedvectors.Vocab at 0x7fad059d5470>,
#  'whitehorse': <gensim.models.keyedvectors.Vocab at 0x7fad05c3e5c0>,
#  '#prague': <gensim.models.keyedvectors.Vocab at 0x7fad05e44fd0>,
#  'friday': <gensim.models.keyedvectors.Vocab at 0x7fad05f85898>,
#  'nytimes': <gensim.models.keyedvectors.Vocab at 0x7fad05cf2208>,
#  '#territorial': <gensim.models.keyedvectors.Vocab at 0x7fad05ea46a0>,
#  'momnets': <gensim.models.keyedvectors.Vocab at 0x7fad05c1a9e8>,
#  '#watchcbs19': <gensim.models.keyedvectors.Vocab at 0x7fad06088b38>,
#  'ष_ब': <gensim.models.keyedvectors.Vocab at 0x7fad058879e8>,
#  '30times': <gensim.models.keyedvectors.Vocab at 0x7fad05e62eb8>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x7fad057352e8>,
#  '#lmthimphu': <gensim.models.keyedvectors.Vocab at 0x7fad05d413c8>,
#  'implement': <gensim.models.keyedvectors.Vocab at 0x7fad05c04ba8>,
#  'metro': <gensim.models.keyedvectors.Vocab at 0x7fad05f9b5f8>,
#  'crux': <gensim.models.keyedvectors.Vocab at 0x7fad05ad8128>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7fad05efc5c0>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7fad05d93f98>,
#  'strides': <gensim.models.keyedvectors.Vocab at 0x7fad05f01d30>,
#  'beautifully': <gensim.models.keyedvectors.Vocab at 0x7fad0594dda0>,
#  'ltr': <gensim.models.keyedvectors.Vocab at 0x7fad05bc25c0>,
#  'charleston': <gensim.models.keyedvectors.Vocab at 0x7fad06057860>,
#  '#besupreme': <gensim.models.keyedvectors.Vocab at 0x7fad061b26d8>,
#  'षदक': <gensim.models.keyedvectors.Vocab at 0x7fad06027dd8>,
#  'daisy': <gensim.models.keyedvectors.Vocab at 0x7fad05d8b518>,
#  'accounting': <gensim.models.keyedvectors.Vocab at 0x7fad05b352e8>,
#  'breking': <gensim.models.keyedvectors.Vocab at 0x7fad05728780>,
#  '#sickhillary': <gensim.models.keyedvectors.Vocab at 0x7fad05a0e5f8>,
#  'amok': <gensim.models.keyedvectors.Vocab at 0x7fad0592ac88>,
#  'n-e': <gensim.models.keyedvectors.Vocab at 0x7fad061452e8>,
#  '2feel': <gensim.models.keyedvectors.Vocab at 0x7fad060ce3c8>,
#  'loves_united_modena': <gensim.models.keyedvectors.Vocab at 0x7fad05b5d9e8>,
#  'releases': <gensim.models.keyedvectors.Vocab at 0x7fad05e3b748>,
#  'งฝน': <gensim.models.keyedvectors.Vocab at 0x7fad05c309e8>,
#  'scolding': <gensim.models.keyedvectors.Vocab at 0x7fad057588d0>,
#  'airing': <gensim.models.keyedvectors.Vocab at 0x7fad0608c710>,
#  '#map': <gensim.models.keyedvectors.Vocab at 0x7fad05f85278>,
#  'clan': <gensim.models.keyedvectors.Vocab at 0x7fad0596c358>,
#  '📢': <gensim.models.keyedvectors.Vocab at 0x7fad059bb1d0>,
#  '#palace': <gensim.models.keyedvectors.Vocab at 0x7fad05887ef0>,
#  'eff': <gensim.models.keyedvectors.Vocab at 0x7fad058838d0>,
#  '408 2527': <gensim.models.keyedvectors.Vocab at 0x7fad05f4fe80>,
#  '#italiasicura': <gensim.models.keyedvectors.Vocab at 0x7fad05e131d0>,
#  'soros': <gensim.models.keyedvectors.Vocab at 0x7fad05dc96a0>,
#  '319.59': <gensim.models.keyedvectors.Vocab at 0x7fad058b3048>,
#  '#ccdccouncilmtg': <gensim.models.keyedvectors.Vocab at 0x7fad05f9f240>,
#  'rahul': <gensim.models.keyedvectors.Vocab at 0x7fad05e8a630>,
#  'volunt': <gensim.models.keyedvectors.Vocab at 0x7fad05967b70>,
#  'bombarding': <gensim.models.keyedvectors.Vocab at 0x7fad05daef98>,
#  'notic': <gensim.models.keyedvectors.Vocab at 0x7fad05c600b8>,
#  'stuf': <gensim.models.keyedvectors.Vocab at 0x7fad0606edd8>,
#  'pagan': <gensim.models.keyedvectors.Vocab at 0x7fad058a66d8>,
#  '77f70': <gensim.models.keyedvectors.Vocab at 0x7fad05d5f9b0>,
#  'disbanded': <gensim.models.keyedvectors.Vocab at 0x7fad05d22ac8>,
#  '25000': <gensim.models.keyedvectors.Vocab at 0x7fad06122400>,
#  'tol': <gensim.models.keyedvectors.Vocab at 0x7fad05fa3358>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7fad05bd8128>,
#  'insurance': <gensim.models.keyedvectors.Vocab at 0x7fad060e00f0>,
#  'chemical': <gensim.models.keyedvectors.Vocab at 0x7fad05e973c8>,
#  '#ii': <gensim.models.keyedvectors.Vocab at 0x7fad057b9128>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7fad05afb160>,
#  'evacuee': <gensim.models.keyedvectors.Vocab at 0x7fad060d71d0>,
#  'vittima': <gensim.models.keyedvectors.Vocab at 0x7fad05ea9320>,
#  'gese': <gensim.models.keyedvectors.Vocab at 0x7fad06057358>,
#  'slipshod': <gensim.models.keyedvectors.Vocab at 0x7fad05cb45c0>,
#  '#goodluck': <gensim.models.keyedvectors.Vocab at 0x7fad05bcf710>,
#  'adalberto': <gensim.models.keyedvectors.Vocab at 0x7fad05a6a780>,
#  'seasick': <gensim.models.keyedvectors.Vocab at 0x7fad05bc7978>,
#  'ambitions': <gensim.models.keyedvectors.Vocab at 0x7fad05f05ef0>,
#  'shacked': <gensim.models.keyedvectors.Vocab at 0x7fad05f59710>,
#  "cesco's": <gensim.models.keyedvectors.Vocab at 0x7fad05f13438>,
#  'restoring': <gensim.models.keyedvectors.Vocab at 0x7fad05d34400>,
#  'initiatief': <gensim.models.keyedvectors.Vocab at 0x7fad05d224a8>,
#  'cracks': <gensim.models.keyedvectors.Vocab at 0x7fad05c11ba8>,
#  'devasting': <gensim.models.keyedvectors.Vocab at 0x7fad05b05f28>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7fad0601f898>,
#  'thoghts': <gensim.models.keyedvectors.Vocab at 0x7fad05f89d68>,
#  '#headlines': <gensim.models.keyedvectors.Vocab at 0x7fad05ad8d68>,
#  'reynol': <gensim.models.keyedvectors.Vocab at 0x7fad05b4f550>,
#  'laurie': <gensim.models.keyedvectors.Vocab at 0x7fad057729b0>,
#  '#fear': <gensim.models.keyedvectors.Vocab at 0x7fad05bf7d30>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fad05974e10>,
#  'chopper': <gensim.models.keyedvectors.Vocab at 0x7fad0587ab00>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7fad05777208>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x7fad0597db38>,
#  '#tanabe': <gensim.models.keyedvectors.Vocab at 0x7fad059a9b38>,
#  'assam': <gensim.models.keyedvectors.Vocab at 0x7fad05f47d68>,
#  'महज': <gensim.models.keyedvectors.Vocab at 0x7fad05bc24e0>,
#  '結構酷い': <gensim.models.keyedvectors.Vocab at 0x7fad05c3e4a8>,
#  'diplomatic': <gensim.models.keyedvectors.Vocab at 0x7fad05daad30>,
#  'jawan': <gensim.models.keyedvectors.Vocab at 0x7fad05cab2b0>,
#  'aeiki': <gensim.models.keyedvectors.Vocab at 0x7fad05a3a780>,
#  '58min': <gensim.models.keyedvectors.Vocab at 0x7fad05dae668>,
#  '#modiwithnep': <gensim.models.keyedvectors.Vocab at 0x7fad05907b38>,
#  'soccer-fball': <gensim.models.keyedvectors.Vocab at 0x7fad05a315c0>,
#  'rimanga': <gensim.models.keyedvectors.Vocab at 0x7fad05b9bb38>,
#  'goddard': <gensim.models.keyedvectors.Vocab at 0x7fad05b42a90>,
#  'iconic': <gensim.models.keyedvectors.Vocab at 0x7fad061571d0>,
#  'earthhquuaaaaakkkeee': <gensim.models.keyedvectors.Vocab at 0x7fad05fcb860>,
#  'nakahama': <gensim.models.keyedvectors.Vocab at 0x7fad06119a20>,
#  'prey': <gensim.models.keyedvectors.Vocab at 0x7fad05f28cf8>,
#  'criminals': <gensim.models.keyedvectors.Vocab at 0x7fad05b05860>,
#  'clockwork': <gensim.models.keyedvectors.Vocab at 0x7fad058cdeb8>,
#  '0053': <gensim.models.keyedvectors.Vocab at 0x7fad05d7ef60>,
#  'trips': <gensim.models.keyedvectors.Vocab at 0x7fad05e97978>,
#  '፣': <gensim.models.keyedvectors.Vocab at 0x7fad05ebf0f0>,
#  'charisma': <gensim.models.keyedvectors.Vocab at 0x7fad05abe9e8>,
#  'asam': <gensim.models.keyedvectors.Vocab at 0x7fad05e0f0f0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7fad061aecc0>,
#  'basks': <gensim.models.keyedvectors.Vocab at 0x7fad05c76940>,
#  'aspect': <gensim.models.keyedvectors.Vocab at 0x7fad057c54a8>,
#  'rites': <gensim.models.keyedvectors.Vocab at 0x7fad0596c208>,
#  'subhead': <gensim.models.keyedvectors.Vocab at 0x7fad05f01a58>,
#  'koruk': <gensim.models.keyedvectors.Vocab at 0x7fad05dec7b8>,
#  'coffin': <gensim.models.keyedvectors.Vocab at 0x7fad05ed9e80>,
#  'communi': <gensim.models.keyedvectors.Vocab at 0x7fad05a438d0>,
#  'sitagu': <gensim.models.keyedvectors.Vocab at 0x7fad058c1358>,
#  'clarita': <gensim.models.keyedvectors.Vocab at 0x7fad05783a58>,
#  'softened': <gensim.models.keyedvectors.Vocab at 0x7fad05af7f60>,
#  '#terremotos': <gensim.models.keyedvectors.Vocab at 0x7fad059f4c88>,
#  "mumbai's": <gensim.models.keyedvectors.Vocab at 0x7fad059d9b00>,
#  'twting': <gensim.models.keyedvectors.Vocab at 0x7fad05e74080>,
#  'sweetest': <gensim.models.keyedvectors.Vocab at 0x7fad060f2748>,
#  'uofr': <gensim.models.keyedvectors.Vocab at 0x7fad05a893c8>,
#  'jamsikhel': <gensim.models.keyedvectors.Vocab at 0x7fad05c11080>,
#  'bass': <gensim.models.keyedvectors.Vocab at 0x7fad05b35cc0>,
#  'lands': <gensim.models.keyedvectors.Vocab at 0x7fad05e86668>,
#  'epalivetwo': <gensim.models.keyedvectors.Vocab at 0x7fad06119358>,
#  '#nazi': <gensim.models.keyedvectors.Vocab at 0x7fad05d15048>,
#  'supportarci': <gensim.models.keyedvectors.Vocab at 0x7fad05852588>,
#  '\U000fe34a': <gensim.models.keyedvectors.Vocab at 0x7fad06039be0>,
#  "#romania's": <gensim.models.keyedvectors.Vocab at 0x7fad0606ed68>,
#  "talya'da": <gensim.models.keyedvectors.Vocab at 0x7fad05fba400>,
#  'italian-americans': <gensim.models.keyedvectors.Vocab at 0x7fad05f3ebe0>,
#  '#vukaafrica': <gensim.models.keyedvectors.Vocab at 0x7fad05e482b0>,
#  '37m': <gensim.models.keyedvectors.Vocab at 0x7fad05760a90>,
#  '07': <gensim.models.keyedvectors.Vocab at 0x7fad05a125c0>,
#  'telengana': <gensim.models.keyedvectors.Vocab at 0x7fad05fcb390>,
#  'newyork': <gensim.models.keyedvectors.Vocab at 0x7fad05cb0748>,
#  'typica': <gensim.models.keyedvectors.Vocab at 0x7fad05dc0128>,
#  'creat': <gensim.models.keyedvectors.Vocab at 0x7fad061577f0>,
#  'parchi': <gensim.models.keyedvectors.Vocab at 0x7fad05f7ce48>,
#  'assemble': <gensim.models.keyedvectors.Vocab at 0x7fad05871d30>,
#  'excruciating': <gensim.models.keyedvectors.Vocab at 0x7fad0590fd68>,
#  '東京ディズニーシー': <gensim.models.keyedvectors.Vocab at 0x7fad05b47550>,
#  '#2009': <gensim.models.keyedvectors.Vocab at 0x7fad05f3a6d8>,
#  'bhaiya': <gensim.models.keyedvectors.Vocab at 0x7fad058b7198>,
#  '#asianews': <gensim.models.keyedvectors.Vocab at 0x7fad058fdd68>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fad05728240>,
#  'himalaya': <gensim.models.keyedvectors.Vocab at 0x7fad05d2ad68>,
#  'trembled': <gensim.models.keyedvectors.Vocab at 0x7fad05c2c048>,
#  'manu': <gensim.models.keyedvectors.Vocab at 0x7fad05beeba8>,
#  'magicians': <gensim.models.keyedvectors.Vocab at 0x7fad060b4fd0>,
#  'wb.tremors': <gensim.models.keyedvectors.Vocab at 0x7fad06011e48>,
#  'resque': <gensim.models.keyedvectors.Vocab at 0x7fad05fea208>,
#  'bottle': <gensim.models.keyedvectors.Vocab at 0x7fad05c659e8>,
#  'robillard': <gensim.models.keyedvectors.Vocab at 0x7fad058a2898>,
#  'latoya': <gensim.models.keyedvectors.Vocab at 0x7fad05a09ba8>,
#  'hairline': <gensim.models.keyedvectors.Vocab at 0x7fad05ff75f8>,
#  'kolkatay': <gensim.models.keyedvectors.Vocab at 0x7fad06122fd0>,
#  '3.03': <gensim.models.keyedvectors.Vocab at 0x7fad05e97518>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x7fad05ed9400>,
#  'inning': <gensim.models.keyedvectors.Vocab at 0x7fad05beacf8>,
#  'shri': <gensim.models.keyedvectors.Vocab at 0x7fad05a24d68>,
#  'weeping': <gensim.models.keyedvectors.Vocab at 0x7fad058b7da0>,
#  'clocktower': <gensim.models.keyedvectors.Vocab at 0x7fad05a3a550>,
#  'nono': <gensim.models.keyedvectors.Vocab at 0x7fad05d93c50>,
#  'jii': <gensim.models.keyedvectors.Vocab at 0x7fad05dfe9e8>,
#  '#devon': <gensim.models.keyedvectors.Vocab at 0x7fad05b09470>,
#  'beside': <gensim.models.keyedvectors.Vocab at 0x7fad0607bf60>,
#  'redevelopmen': <gensim.models.keyedvectors.Vocab at 0x7fad05a36a90>,
#  'job-past': <gensim.models.keyedvectors.Vocab at 0x7fad05c99ac8>,
#  'mps': <gensim.models.keyedvectors.Vocab at 0x7fad05e0b4e0>,
#  'today.the': <gensim.models.keyedvectors.Vocab at 0x7fad05e67ac8>,
#  "disaster-earthquake-doesn't": <gensim.models.keyedvectors.Vocab at 0x7fad057fbd30>,
#  '40s': <gensim.models.keyedvectors.Vocab at 0x7fad0606e7f0>,
#  'discretion': <gensim.models.keyedvectors.Vocab at 0x7fad05a85b70>,
#  'allegedly': <gensim.models.keyedvectors.Vocab at 0x7fad05860080>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x7fad0577be48>,
#  'nightwishers': <gensim.models.keyedvectors.Vocab at 0x7fad06115400>,
#  '93.3': <gensim.models.keyedvectors.Vocab at 0x7fad05f1fc88>,
#  'nrcan': <gensim.models.keyedvectors.Vocab at 0x7fad0575cb70>,
#  'audience': <gensim.models.keyedvectors.Vocab at 0x7fad05af7748>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x7fad05ed1cc0>,
#  'fairport': <gensim.models.keyedvectors.Vocab at 0x7fad05da15f8>,
#  'liczba': <gensim.models.keyedvectors.Vocab at 0x7fad05e972b0>,
#  'there.aquila': <gensim.models.keyedvectors.Vocab at 0x7fad0604aac8>,
#  'philadelphia': <gensim.models.keyedvectors.Vocab at 0x7fad0601fc88>,
#  '🕊': <gensim.models.keyedvectors.Vocab at 0x7fad059cc7b8>,
#  'christian': <gensim.models.keyedvectors.Vocab at 0x7fad05fc23c8>,
#  '#msf': <gensim.models.keyedvectors.Vocab at 0x7fad05791ac8>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7fad05f01748>,
#  '#blackdayforallnepalese': <gensim.models.keyedvectors.Vocab at 0x7fad05e5eeb8>,
#  'advisory': <gensim.models.keyedvectors.Vocab at 0x7fad05b00710>,
#  'recriminatio': <gensim.models.keyedvectors.Vocab at 0x7fad05f9b240>,
#  'enrolled': <gensim.models.keyedvectors.Vocab at 0x7fad05a9f828>,
#  'bio': <gensim.models.keyedvectors.Vocab at 0x7fad060b4748>,
#  '126.50': <gensim.models.keyedvectors.Vocab at 0x7fad05a81518>,
#  'portent': <gensim.models.keyedvectors.Vocab at 0x7fad0597d438>,
#  '#euler': <gensim.models.keyedvectors.Vocab at 0x7fad05aeaf98>,
#  'wszędzie': <gensim.models.keyedvectors.Vocab at 0x7fad05d41748>,
#  'tommaso': <gensim.models.keyedvectors.Vocab at 0x7fad061ae128>,
#  'यस': <gensim.models.keyedvectors.Vocab at 0x7fad05f17908>,
#  '#lasvegas': <gensim.models.keyedvectors.Vocab at 0x7fad05a9a8d0>,
#  "giovanni's": <gensim.models.keyedvectors.Vocab at 0x7fad05e3bf60>,
#  'tasting': <gensim.models.keyedvectors.Vocab at 0x7fad05b895c0>,
#  "all's": <gensim.models.keyedvectors.Vocab at 0x7fad06126cf8>,
#  'ses': <gensim.models.keyedvectors.Vocab at 0x7fad05e6cd68>,
#  'cgi': <gensim.models.keyedvectors.Vocab at 0x7fad05ec3ef0>,
#  'zvezda': <gensim.models.keyedvectors.Vocab at 0x7fad05e67470>,
#  'sarvodaya': <gensim.models.keyedvectors.Vocab at 0x7fad05a78198>,
#  'down.no': <gensim.models.keyedvectors.Vocab at 0x7fad05e02470>,
#  'slight': <gensim.models.keyedvectors.Vocab at 0x7fad05974f28>,
#  'kasto': <gensim.models.keyedvectors.Vocab at 0x7fad05f73e10>,
#  'crown': <gensim.models.keyedvectors.Vocab at 0x7fad05f47710>,
#  'prev': <gensim.models.keyedvectors.Vocab at 0x7fad05981160>,
#  'peace.kamran': <gensim.models.keyedvectors.Vocab at 0x7fad05bd3588>,
#  '@bkk': <gensim.models.keyedvectors.Vocab at 0x7fad0579a710>,
#  'residency': <gensim.models.keyedvectors.Vocab at 0x7fad057b0320>,
#  'cent': <gensim.models.keyedvectors.Vocab at 0x7fad060a7400>,
#  'guilt': <gensim.models.keyedvectors.Vocab at 0x7fad05898f28>,
#  'kharagpur': <gensim.models.keyedvectors.Vocab at 0x7fad05a175c0>,
#  '#lesliejones': <gensim.models.keyedvectors.Vocab at 0x7fad0593bf28>,
#  'soldiers': <gensim.models.keyedvectors.Vocab at 0x7fad0582f6a0>,
#  'accomodate': <gensim.models.keyedvectors.Vocab at 0x7fad060ff9e8>,
#  '3,954': <gensim.models.keyedvectors.Vocab at 0x7fad05de8d30>,
#  'earthquake.supposed': <gensim.models.keyedvectors.Vocab at 0x7fad06183f60>,
#  "husband's": <gensim.models.keyedvectors.Vocab at 0x7fad060a7c18>,
#  '#didyouknow': <gensim.models.keyedvectors.Vocab at 0x7fad061bc898>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x7fad05ad80f0>,
#  'sliders': <gensim.models.keyedvectors.Vocab at 0x7fad0615fef0>,
#  'linda': <gensim.models.keyedvectors.Vocab at 0x7fad05e36550>,
#  'udhar': <gensim.models.keyedvectors.Vocab at 0x7fad060809b0>,
#  'galasso': <gensim.models.keyedvectors.Vocab at 0x7fad05810f60>,
#  'especi': <gensim.models.keyedvectors.Vocab at 0x7fad06027518>,
#  '👁': <gensim.models.keyedvectors.Vocab at 0x7fad05b30668>,
#  '#emiliaromagna': <gensim.models.keyedvectors.Vocab at 0x7fad05e216a0>,
#  '63': <gensim.models.keyedvectors.Vocab at 0x7fad057b48d0>,
#  'dead--searches': <gensim.models.keyedvectors.Vocab at 0x7fad058388d0>,
#  '69': <gensim.models.keyedvectors.Vocab at 0x7fad05826be0>,
#  '#tavullia': <gensim.models.keyedvectors.Vocab at 0x7fad05b475c0>,
#  'tmc': <gensim.models.keyedvectors.Vocab at 0x7fad05fb5128>,
#  '#preppen': <gensim.models.keyedvectors.Vocab at 0x7fad05e9b358>,
#  'inches': <gensim.models.keyedvectors.Vocab at 0x7fad057163c8>,
#  'embassie': <gensim.models.keyedvectors.Vocab at 0x7fad05e4d048>,
#  'rajn': <gensim.models.keyedvectors.Vocab at 0x7fad05e51240>,
#  'climber': <gensim.models.keyedvectors.Vocab at 0x7fad060849e8>,
#  'emir': <gensim.models.keyedvectors.Vocab at 0x7fad060ffd68>,
#  're-hashed': <gensim.models.keyedvectors.Vocab at 0x7fad05d03c18>,
#  '#mountains': <gensim.models.keyedvectors.Vocab at 0x7fad05948470>,
#  'highschoolride': <gensim.models.keyedvectors.Vocab at 0x7fad05d64c50>,
#  'telecast': <gensim.models.keyedvectors.Vocab at 0x7fad05dd1ac8>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7fad05f01358>,
#  'bilingual': <gensim.models.keyedvectors.Vocab at 0x7fad05a96128>,
#  'floods': <gensim.models.keyedvectors.Vocab at 0x7fad06023f28>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x7fad05903a58>,
#  'heads-up': <gensim.models.keyedvectors.Vocab at 0x7fad05cf2c18>,
#  'almazbek': <gensim.models.keyedvectors.Vocab at 0x7fad05b13358>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7fad059cc9e8>,
#  '267.400': <gensim.models.keyedvectors.Vocab at 0x7fad05ef44e0>,
#  'expats': <gensim.models.keyedvectors.Vocab at 0x7fad05c1a438>,
#  '#aircraft': <gensim.models.keyedvectors.Vocab at 0x7fad0617e4e0>,
#  '#ww2': <gensim.models.keyedvectors.Vocab at 0x7fad05bb07f0>,
#  '155.279': <gensim.models.keyedvectors.Vocab at 0x7fad060b8cf8>,
#  'dx': <gensim.models.keyedvectors.Vocab at 0x7fad06069cc0>,
# ...
#  'medician': <gensim.models.keyedvectors.Vocab at 0x7fad058522b0>,
#  'तरह': <gensim.models.keyedvectors.Vocab at 0x7fad05c5cb00>,
#  'provoked': <gensim.models.keyedvectors.Vocab at 0x7fad05dd5198>,
#  'proselytizing': <gensim.models.keyedvectors.Vocab at 0x7fad05d764a8>,
#  '#town': <gensim.models.keyedvectors.Vocab at 0x7fad05fe16d8>,
#  'vadra': <gensim.models.keyedvectors.Vocab at 0x7fad05d38d30>,
#  'mya': <gensim.models.keyedvectors.Vocab at 0x7fad0584df28>,
#  'ucc': <gensim.models.keyedvectors.Vocab at 0x7fad058cd160>,
#  'displacing': <gensim.models.keyedvectors.Vocab at 0x7fad059f4be0>,
#  'ie': <gensim.models.keyedvectors.Vocab at 0x7fad0607bb00>,
#  'khal': <gensim.models.keyedvectors.Vocab at 0x7fad05f174e0>,
#  'family-of-four': <gensim.models.keyedvectors.Vocab at 0x7fad05a12e10>,
#  'forcendtvnew': <gensim.models.keyedvectors.Vocab at 0x7fad06034160>,
#  '#cycling': <gensim.models.keyedvectors.Vocab at 0x7fad05aa4160>,
#  '#montepulciano': <gensim.models.keyedvectors.Vocab at 0x7fad05777c88>,
#  'yrf': <gensim.models.keyedvectors.Vocab at 0x7fad05fe1be0>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x7fad05de8588>,
#  'भव': <gensim.models.keyedvectors.Vocab at 0x7fad05e36940>,
#  'povoled': <gensim.models.keyedvectors.Vocab at 0x7fad05f59390>,
#  'secy': <gensim.models.keyedvectors.Vocab at 0x7fad06091240>,
#  'moms': <gensim.models.keyedvectors.Vocab at 0x7fad05894748>,
#  'trainings': <gensim.models.keyedvectors.Vocab at 0x7fad058ecf60>,
#  "reuters's": <gensim.models.keyedvectors.Vocab at 0x7fad05868d68>,
#  'sovereignty': <gensim.models.keyedvectors.Vocab at 0x7fad057c9898>,
#  'fighting': <gensim.models.keyedvectors.Vocab at 0x7fad05a78a58>,
#  'deaparted': <gensim.models.keyedvectors.Vocab at 0x7fad05b5dc18>,
#  'khou': <gensim.models.keyedvectors.Vocab at 0x7fad05fcfe10>,
#  '13.165': <gensim.models.keyedvectors.Vocab at 0x7fad05a54240>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x7fad05d380b8>,
#  'tembl': <gensim.models.keyedvectors.Vocab at 0x7fad05be1710>,
#  'oversee': <gensim.models.keyedvectors.Vocab at 0x7fad05753160>,
#  '6:12-': <gensim.models.keyedvectors.Vocab at 0x7fad05b59f60>,
#  'sud': <gensim.models.keyedvectors.Vocab at 0x7fad0611def0>,
#  'dollar': <gensim.models.keyedvectors.Vocab at 0x7fad05a09c50>,
#  '12:54': <gensim.models.keyedvectors.Vocab at 0x7fad05b54b70>,
#  '#deutsche': <gensim.models.keyedvectors.Vocab at 0x7fad0588b748>,
#  '#survivalguide': <gensim.models.keyedvectors.Vocab at 0x7fad0587f320>,
#  '#heartwarming': <gensim.models.keyedvectors.Vocab at 0x7fad05760668>,
#  '#lettherebelight': <gensim.models.keyedvectors.Vocab at 0x7fad059e6400>,
#  'shitting': <gensim.models.keyedvectors.Vocab at 0x7fad05e17cf8>,
#  'cbdt': <gensim.models.keyedvectors.Vocab at 0x7fad05ea4d30>,
#  'ल-ब': <gensim.models.keyedvectors.Vocab at 0x7fad05d26470>,
#  '#aiutareitalia': <gensim.models.keyedvectors.Vocab at 0x7fad05e17fd0>,
#  '136km': <gensim.models.keyedvectors.Vocab at 0x7fad05b9b160>,
#  'muy': <gensim.models.keyedvectors.Vocab at 0x7fad05b1fa58>,
#  'grocery': <gensim.models.keyedvectors.Vocab at 0x7fad05a81160>,
#  'ks': <gensim.models.keyedvectors.Vocab at 0x7fad05e55e10>,
#  '2246': <gensim.models.keyedvectors.Vocab at 0x7fad060fa208>,
#  'disintegrated': <gensim.models.keyedvectors.Vocab at 0x7fad05e8ffd0>,
#  'radyo': <gensim.models.keyedvectors.Vocab at 0x7fad05b548d0>,
#  'wazobia': <gensim.models.keyedvectors.Vocab at 0x7fad05ae61d0>,
#  '... ...': <gensim.models.keyedvectors.Vocab at 0x7fad05a9ac88>,
#  'ghoul': <gensim.models.keyedvectors.Vocab at 0x7fad058e4be0>,
#  "heart's": <gensim.models.keyedvectors.Vocab at 0x7fad06095cc0>,
#  'kaif': <gensim.models.keyedvectors.Vocab at 0x7fad060ab518>,
#  '6,1': <gensim.models.keyedvectors.Vocab at 0x7fad05b74c18>,
#  '#accumuli': <gensim.models.keyedvectors.Vocab at 0x7fad05a475c0>,
#  'momma': <gensim.models.keyedvectors.Vocab at 0x7fad05ab98d0>,
#  'i-it': <gensim.models.keyedvectors.Vocab at 0x7fad05a890f0>,
#  'ancestry': <gensim.models.keyedvectors.Vocab at 0x7fad05918048>,
#  '#demexit': <gensim.models.keyedvectors.Vocab at 0x7fad05bc7ac8>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7fad05c39048>,
#  'wah': <gensim.models.keyedvectors.Vocab at 0x7fad058fd438>,
#  'ianthekirkland': <gensim.models.keyedvectors.Vocab at 0x7fad05fb05f8>,
#  'affrs': <gensim.models.keyedvectors.Vocab at 0x7fad05fc2f60>,
#  '#prabalgurung': <gensim.models.keyedvectors.Vocab at 0x7fad05a3f6d8>,
#  '#coraggio': <gensim.models.keyedvectors.Vocab at 0x7fad060a2710>,
#  '#collagenbabe': <gensim.models.keyedvectors.Vocab at 0x7fad05d7ec88>,
#  'mans': <gensim.models.keyedvectors.Vocab at 0x7fad05d0b240>,
#  '5:52': <gensim.models.keyedvectors.Vocab at 0x7fad060151d0>,
#  'quirks': <gensim.models.keyedvectors.Vocab at 0x7fad05cb04e0>,
#  '#bigshot': <gensim.models.keyedvectors.Vocab at 0x7fad057bd6a0>,
#  'pretare': <gensim.models.keyedvectors.Vocab at 0x7fad05b59a58>,
#  '29624': <gensim.models.keyedvectors.Vocab at 0x7fad058f5f28>,
#  'ubi': <gensim.models.keyedvectors.Vocab at 0x7fad05f89f60>,
#  '#companion': <gensim.models.keyedvectors.Vocab at 0x7fad060767b8>,
#  'burwash': <gensim.models.keyedvectors.Vocab at 0x7fad05f47f60>,
#  'thronging': <gensim.models.keyedvectors.Vocab at 0x7fad057edba8>,
#  'altri': <gensim.models.keyedvectors.Vocab at 0x7fad05acf5c0>,
#  'artificially': <gensim.models.keyedvectors.Vocab at 0x7fad05b05358>,
#  'joks': <gensim.models.keyedvectors.Vocab at 0x7fad06122ac8>,
#  'asserts': <gensim.models.keyedvectors.Vocab at 0x7fad05cd33c8>,
#  '#italyerthquake': <gensim.models.keyedvectors.Vocab at 0x7fad05871f60>,
#  'ultra-squeezes': <gensim.models.keyedvectors.Vocab at 0x7fad05e67eb8>,
#  '#love': <gensim.models.keyedvectors.Vocab at 0x7fad05daed30>,
#  '#akutan': <gensim.models.keyedvectors.Vocab at 0x7fad061ae400>,
#  'joost': <gensim.models.keyedvectors.Vocab at 0x7fad060db588>,
#  '#napoli': <gensim.models.keyedvectors.Vocab at 0x7fad05c30588>,
#  'thirdday': <gensim.models.keyedvectors.Vocab at 0x7fad05f24710>,
#  'बन': <gensim.models.keyedvectors.Vocab at 0x7fad057a65c0>,
#  'handicapness': <gensim.models.keyedvectors.Vocab at 0x7fad05eeb908>,
#  'subramanian': <gensim.models.keyedvectors.Vocab at 0x7fad05772a58>,
#  'sich': <gensim.models.keyedvectors.Vocab at 0x7fad06000c50>,
#  'cjob': <gensim.models.keyedvectors.Vocab at 0x7fad05fa3a90>,
#  'earthquake-like': <gensim.models.keyedvectors.Vocab at 0x7fad05f6eeb8>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x7fad057ceeb8>,
#  'nationally': <gensim.models.keyedvectors.Vocab at 0x7fad05dc0240>,
#  'messy': <gensim.models.keyedvectors.Vocab at 0x7fad05f32da0>,
#  'dumped': <gensim.models.keyedvectors.Vocab at 0x7fad0617ef28>,
#  'random-and-interesting': <gensim.models.keyedvectors.Vocab at 0x7fad05a73e10>,
#  'raju': <gensim.models.keyedvectors.Vocab at 0x7fad057ff7b8>,
#  'tackle': <gensim.models.keyedvectors.Vocab at 0x7fad05a3fa58>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fad06011c50>,
#  'sosad': <gensim.models.keyedvectors.Vocab at 0x7fad0587fe10>,
#  'hecking': <gensim.models.keyedvectors.Vocab at 0x7fad05a5d978>,
#  '10am': <gensim.models.keyedvectors.Vocab at 0x7fad059a49b0>,
#  'cheers': <gensim.models.keyedvectors.Vocab at 0x7fad05814828>,
#  'joseph': <gensim.models.keyedvectors.Vocab at 0x7fad05e2ae48>,
#  'chamber': <gensim.models.keyedvectors.Vocab at 0x7fad05f8d160>,
#  'ibm': <gensim.models.keyedvectors.Vocab at 0x7fad061c0240>,
#  'dio': <gensim.models.keyedvectors.Vocab at 0x7fad05efc3c8>,
#  '308': <gensim.models.keyedvectors.Vocab at 0x7fad060d3400>,
#  'daaaammmnnnnn': <gensim.models.keyedvectors.Vocab at 0x7fad05e8ac50>,
#  'opera': <gensim.models.keyedvectors.Vocab at 0x7fad05997e10>,
#  '#farmer': <gensim.models.keyedvectors.Vocab at 0x7fad05f282e8>,
#  'usatoday': <gensim.models.keyedvectors.Vocab at 0x7fad05fddf60>,
#  'deaths.protezione': <gensim.models.keyedvectors.Vocab at 0x7fad05de8e80>,
#  'seattle': <gensim.models.keyedvectors.Vocab at 0x7fad05772668>,
#  'amanecer': <gensim.models.keyedvectors.Vocab at 0x7fad05b74b00>,
#  'mediteraean': <gensim.models.keyedvectors.Vocab at 0x7fad05aea6a0>,
#  'asoke': <gensim.models.keyedvectors.Vocab at 0x7fad05b85400>,
#  'infowars': <gensim.models.keyedvectors.Vocab at 0x7fad05a20d30>,
#  'grandma': <gensim.models.keyedvectors.Vocab at 0x7fad05cf2438>,
#  'violations': <gensim.models.keyedvectors.Vocab at 0x7fad05920c18>,
#  'guidnce': <gensim.models.keyedvectors.Vocab at 0x7fad05ad44e0>,
#  'gap': <gensim.models.keyedvectors.Vocab at 0x7fad05c15748>,
#  '#aaos': <gensim.models.keyedvectors.Vocab at 0x7fad05f17e48>,
#  '17:06': <gensim.models.keyedvectors.Vocab at 0x7fad05a31208>,
#  'troys': <gensim.models.keyedvectors.Vocab at 0x7fad057bd358>,
#  '309': <gensim.models.keyedvectors.Vocab at 0x7fad05e401d0>,
#  'crying.this': <gensim.models.keyedvectors.Vocab at 0x7fad05c65518>,
#  '#hiphop': <gensim.models.keyedvectors.Vocab at 0x7fad0603e978>,
#  '#prayersamatrice': <gensim.models.keyedvectors.Vocab at 0x7fad05997eb8>,
#  'motherfucken': <gensim.models.keyedvectors.Vocab at 0x7fad058aac50>,
#  '空から見た被災地': <gensim.models.keyedvectors.Vocab at 0x7fad057162b0>,
#  'notifications': <gensim.models.keyedvectors.Vocab at 0x7fad05fa8e80>,
#  'swivelled': <gensim.models.keyedvectors.Vocab at 0x7fad059bfac8>,
#  'corazon': <gensim.models.keyedvectors.Vocab at 0x7fad059f41d0>,
#  '#bppost': <gensim.models.keyedvectors.Vocab at 0x7fad06088e48>,
#  'bangalore': <gensim.models.keyedvectors.Vocab at 0x7fad05819240>,
#  'damag': <gensim.models.keyedvectors.Vocab at 0x7fad05cce860>,
#  'aunty': <gensim.models.keyedvectors.Vocab at 0x7fad05c53198>,
#  '#wednesday': <gensim.models.keyedvectors.Vocab at 0x7fad060e96d8>,
#  'probs': <gensim.models.keyedvectors.Vocab at 0x7fad059a9550>,
#  'bo': <gensim.models.keyedvectors.Vocab at 0x7fad058644a8>,
#  'guidelines': <gensim.models.keyedvectors.Vocab at 0x7fad0592e5f8>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7fad057c1be0>,
#  '#blessings': <gensim.models.keyedvectors.Vocab at 0x7fad058dec50>,
#  '#ue': <gensim.models.keyedvectors.Vocab at 0x7fad05fba550>,
#  'vtime': <gensim.models.keyedvectors.Vocab at 0x7fad06110e80>,
#  'spirits': <gensim.models.keyedvectors.Vocab at 0x7fad06027ef0>,
#  'crummy': <gensim.models.keyedvectors.Vocab at 0x7fad058b3dd8>,
#  '#restoringkindness': <gensim.models.keyedvectors.Vocab at 0x7fad06103240>,
#  'remarkable': <gensim.models.keyedvectors.Vocab at 0x7fad05a0e9b0>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7fad05a2d048>,
#  '#struck': <gensim.models.keyedvectors.Vocab at 0x7fad058834a8>,
#  'by-komaungmaungoo': <gensim.models.keyedvectors.Vocab at 0x7fad058fdba8>,
#  'eto': <gensim.models.keyedvectors.Vocab at 0x7fad05ea9780>,
#  '⒍': <gensim.models.keyedvectors.Vocab at 0x7fad05c76390>,
#  'early.there': <gensim.models.keyedvectors.Vocab at 0x7fad05d51400>,
#  '#eucivpro': <gensim.models.keyedvectors.Vocab at 0x7fad05ced358>,
#  'guelph': <gensim.models.keyedvectors.Vocab at 0x7fad05e7d438>,
#  '5901': <gensim.models.keyedvectors.Vocab at 0x7fad05f01da0>,
#  'morn.with': <gensim.models.keyedvectors.Vocab at 0x7fad060046a0>,
#  'mayanmer': <gensim.models.keyedvectors.Vocab at 0x7fad05932ac8>,
#  'inevitable': <gensim.models.keyedvectors.Vocab at 0x7fad05e0b7f0>,
#  'legend': <gensim.models.keyedvectors.Vocab at 0x7fad06141cf8>,
#  '#letshelp': <gensim.models.keyedvectors.Vocab at 0x7fad05a0ee48>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x7fad059f42e8>,
#  '#regularthings': <gensim.models.keyedvectors.Vocab at 0x7fad058cdd30>,
#  '#aerial': <gensim.models.keyedvectors.Vocab at 0x7fad05e5eac8>,
#  'doin': <gensim.models.keyedvectors.Vocab at 0x7fad0601f4e0>,
#  'pdt': <gensim.models.keyedvectors.Vocab at 0x7fad0613cc88>,
#  'dat': <gensim.models.keyedvectors.Vocab at 0x7fad05920588>,
#  'pisa': <gensim.models.keyedvectors.Vocab at 0x7fad05a28898>,
#  '#alllivesmatter': <gensim.models.keyedvectors.Vocab at 0x7fad05ac32e8>,
#  'finanzas': <gensim.models.keyedvectors.Vocab at 0x7fad05e558d0>,
#  'conditon': <gensim.models.keyedvectors.Vocab at 0x7fad05a50ba8>,
#  'rlwys': <gensim.models.keyedvectors.Vocab at 0x7fad05753518>,
#  'newsearthquake': <gensim.models.keyedvectors.Vocab at 0x7fad05f3ec50>,
#  '#sumatra': <gensim.models.keyedvectors.Vocab at 0x7fad05849c18>,
#  'bus-involved': <gensim.models.keyedvectors.Vocab at 0x7fad060b4cf8>,
#  '#yeman': <gensim.models.keyedvectors.Vocab at 0x7fad05fa82e8>,
#  '#vallenar': <gensim.models.keyedvectors.Vocab at 0x7fad05db2320>,
#  'yameen': <gensim.models.keyedvectors.Vocab at 0x7fad05bcbf98>,
#  'contacting': <gensim.models.keyedvectors.Vocab at 0x7fad05a7c710>,
#  'messing': <gensim.models.keyedvectors.Vocab at 0x7fad05cf2710>,
#  'srilnka': <gensim.models.keyedvectors.Vocab at 0x7fad060dbf60>,
#  'baat': <gensim.models.keyedvectors.Vocab at 0x7fad058fdc88>,
#  '#eathquake': <gensim.models.keyedvectors.Vocab at 0x7fad05ab5c88>,
#  '#gallery': <gensim.models.keyedvectors.Vocab at 0x7fad05a92748>,
#  'कप': <gensim.models.keyedvectors.Vocab at 0x7fad05da6588>,
#  'globalgiving': <gensim.models.keyedvectors.Vocab at 0x7fad05fb53c8>,
#  '2301': <gensim.models.keyedvectors.Vocab at 0x7fad05e36f28>,
#  'palistan': <gensim.models.keyedvectors.Vocab at 0x7fad06149588>,
#  "diamond's": <gensim.models.keyedvectors.Vocab at 0x7fad059f4fd0>,
#  'blamin': <gensim.models.keyedvectors.Vocab at 0x7fad0575ca90>,
#  'สน': <gensim.models.keyedvectors.Vocab at 0x7fad0580b780>,
#  "bagan's": <gensim.models.keyedvectors.Vocab at 0x7fad05cb4668>,
#  'pakis': <gensim.models.keyedvectors.Vocab at 0x7fad05cab7f0>,
#  'dilemma': <gensim.models.keyedvectors.Vocab at 0x7fad058496d8>,
#  'hears': <gensim.models.keyedvectors.Vocab at 0x7fad05adcdd8>,
#  '#keeptheminprayers': <gensim.models.keyedvectors.Vocab at 0x7fad05b4b080>,
#  'gray': <gensim.models.keyedvectors.Vocab at 0x7fad05eae080>,
#  'italijani': <gensim.models.keyedvectors.Vocab at 0x7fad05fac668>,
#  'canberra': <gensim.models.keyedvectors.Vocab at 0x7fad05a207b8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7fad05864048>,
#  'telegraphtravel': <gensim.models.keyedvectors.Vocab at 0x7fad0575cd68>,
#  '#jishin': <gensim.models.keyedvectors.Vocab at 0x7fad06134748>,
#  '#tv': <gensim.models.keyedvectors.Vocab at 0x7fad059f49b0>,
#  't07': <gensim.models.keyedvectors.Vocab at 0x7fad05c606a0>,
#  '0472': <gensim.models.keyedvectors.Vocab at 0x7fad0617ae10>,
#  'flights': <gensim.models.keyedvectors.Vocab at 0x7fad059f8eb8>,
#  'immediately': <gensim.models.keyedvectors.Vocab at 0x7fad059cc588>,
#  '#geological': <gensim.models.keyedvectors.Vocab at 0x7fad060f2518>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x7fad05a2d2b0>,
#  'thanked': <gensim.models.keyedvectors.Vocab at 0x7fad06176fd0>,
#  '#perppers': <gensim.models.keyedvectors.Vocab at 0x7fad06060e80>,
#  'qualitat': <gensim.models.keyedvectors.Vocab at 0x7fad05d5ff60>,
#  'como': <gensim.models.keyedvectors.Vocab at 0x7fad05e44cf8>,
#  'gianluigi': <gensim.models.keyedvectors.Vocab at 0x7fad05d877f0>,
#  'eqs': <gensim.models.keyedvectors.Vocab at 0x7fad05cff048>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7fad05ab10b8>,
#  'priorities': <gensim.models.keyedvectors.Vocab at 0x7fad05f9b390>,
#  'smrd': <gensim.models.keyedvectors.Vocab at 0x7fad06015978>,
#  'rally': <gensim.models.keyedvectors.Vocab at 0x7fad0592a8d0>,
#  'turkish': <gensim.models.keyedvectors.Vocab at 0x7fad0579ea20>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x7fad05d030b8>,
#  'retrofitted': <gensim.models.keyedvectors.Vocab at 0x7fad05aeaa20>,
#  'sobering': <gensim.models.keyedvectors.Vocab at 0x7fad061b2320>,
#  'smashed': <gensim.models.keyedvectors.Vocab at 0x7fad057e42e8>,
#  'habi': <gensim.models.keyedvectors.Vocab at 0x7fad061b8f28>,
#  'capire': <gensim.models.keyedvectors.Vocab at 0x7fad05a3f2b0>,
#  '#sikkim': <gensim.models.keyedvectors.Vocab at 0x7fad05e625c0>,
#  'frikkin': <gensim.models.keyedvectors.Vocab at 0x7fad05f3e208>,
#  'intellectuals': <gensim.models.keyedvectors.Vocab at 0x7fad05fdd8d0>,
#  'හ': <gensim.models.keyedvectors.Vocab at 0x7fad05a85d30>,
#  'hchhe': <gensim.models.keyedvectors.Vocab at 0x7fad0576e358>,
#  '#detain': <gensim.models.keyedvectors.Vocab at 0x7fad060d30b8>,
#  '#despite': <gensim.models.keyedvectors.Vocab at 0x7fad057e4208>,
#  'grumpy': <gensim.models.keyedvectors.Vocab at 0x7fad058cdc50>,
#  ...}

# %%
model.wv.most_similar("earthqu")
# Out:
# [('earthqua', 0.9215565919876099),
#  ('earthquak', 0.9150896668434143),
#  ('ea', 0.9072723388671875),
#  ('earthq', 0.8954514861106873),
#  ('stru', 0.8892335295677185),
#  ('eart', 0.885019838809967),
#  ('ear', 0.8746320009231567),
#  ('magni', 0.8590549230575562),
#  ('str', 0.8358259201049805),
#  ('#endofdays', 0.8130565881729126)]

# %%
model.wv.similarity('earthquak', 'earthqua')
# Out:
# 0.86933157614144663

# %%
hede = '12345'

# %%
if 1 < len(hede) < 5:
    print(hede)

# %%
editdistance.eval('earthquak', 'earthqu')
# Out:
# 2

# %%
editdistance.eval('earthquak', 'earthqu')
